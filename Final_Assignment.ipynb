# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hiu Hin Tam**
#
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because it makes huge incomes._

# %% [markdown]
# ### The demonstrateion of printing 'Hello World'

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# > Being new in Jupiter Notebook
# >
#  - Feel Good
#  - Nice!
#
# <hr>
#
# Go to [my Github page](https://github.com/hiuhintam3/Testing1/)
